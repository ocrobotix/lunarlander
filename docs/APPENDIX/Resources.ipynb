# %% [markdown]
# # Resources
# (References, Reports & Data Sources arranged alphabetically)

# %% [markdown]
# **Apollo 11 Mission Report**
# https://www.nasa.gov/wp-content/uploads/static/history/alsj/a11/a11_missionreport.pdf

# %% [markdown]
# **Landing Ellipse**
# https://www.space.com/apollo-11-risky-moon-landing-dangers.html
# https://phys.org/news/2020-09-nasa-technology-enables-precision.html

# %% [markdown]
# **LOLA PDS Data Node**
# ![image.png](attachment:047b0108-37a9-4f04-b95c-444d963ffbef.png)
# Raw and processed data from the Lunar Orbiter Laser Altimeter (LOLA)
# https://imbrium.mit.edu

# %% [markdown]
# **NASA Goddard Scientific Visualization Studio**
# ![image.png](attachment:74b71bd9-dc27-4164-a5e1-6fe5a59f37c1.png)
# Latest images and videos from ongoing LRO mission
# https://svs.gsfc.nasa.gov/gallery/lunar-reconnaissance-orbiter/

# %% [markdown]
# **NASA Technical Report Server**
# ![image.png](attachment:0b19b178-3af8-4efd-90cd-c57b13783ba2.png)
# https://ntrs.nasa.gov/

# %% [markdown]
# **PDS Geosciences Node Lunar Orbital Data Explorer**
# ![image.png](attachment:25d21aad-a134-4064-ba9a-9c13e4df98a9.png)
# Data from multiple lunar missions, including Lunar Reconnaissance Orbiter (LRO),  Gravity Recovery and Interior Laboratory (GRAIL), SELENE (JAXA), and Chandrayaan-1 (ISRO)
# https://ode.rsl.wustl.edu/moon/index.aspx

# %% [markdown]
# . . .
